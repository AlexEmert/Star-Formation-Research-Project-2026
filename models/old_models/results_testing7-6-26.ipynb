# %% [markdown]
# # Analysis of Results after removing snr and adding function that expands bounds of search

# %%
import pickle
import numpy as np
import pandas as pd
from pyhere import here
import matplotlib.pyplot as plt
from ratio_function import RatioGenerator, LogRatioGenerator
import itertools
from plotnine import *
from sklearn.model_selection import train_test_split
from sklearn import set_config
from skopt import BayesSearchCV
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.preprocessing import StandardScaler, RobustScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import cross_val_score, cross_validate, KFold
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.base import clone
from sklearn.inspection import permutation_importance

set_config(transform_output="pandas")

# %%
remove_properties = ['LRATIO', 'T_BOL', 'LM', 'L_BOL', 'MASS', 'DIAM', 'SURF_DENS', 'TEMP']

for property in remove_properties:
    with open(here("pipeline/results/old_results/late_june-early_july_results", f"{property}_lowflux_results6_30_26.pkl"), "rb") as file:
        results = pickle.load(file) 

    print(property)
    print(results['xgb_params'])
# Out:
# LRATIO
# OrderedDict({'impute': SimpleImputer(), 'model__colsample_bylevel': 1.0, 'model__colsample_bytree': 0.7352520871333101, 'model__gamma': 7.839899433955562e-08, 'model__learning_rate': 0.008414699026718403, 'model__max_depth': 4, 'model__min_child_weight': 1, 'model__n_estimators': 954, 'model__reg_alpha': 0.018779407755215395, 'model__reg_lambda': 5.837889931037462e-11, 'model__subsample': 0.6027189436568673, 'ratio': 'passthrough', 'scale': RobustScaler()})
# T_BOL
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.35230091497539057, 'model__colsample_bytree': 0.9200350009191018, 'model__gamma': 1.8717998089667244e-08, 'model__learning_rate': 0.00401317999478738, 'model__max_depth': 3, 'model__min_child_weight': 23, 'model__n_estimators': 2629, 'model__reg_alpha': 9.593250017732196e-06, 'model__reg_lambda': 7.906121062683112e-12, 'model__subsample': 0.41896964980021884, 'ratio': RatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': RobustScaler()})
# LM
# OrderedDict({'impute': SimpleImputer(strategy='median'), 'model__colsample_bylevel': 0.771463490154592, 'model__colsample_bytree': 1.0, 'model__gamma': 2.4908770689717983, 'model__learning_rate': 0.0022810967400344454, 'model__max_depth': 3, 'model__min_child_weight': 29, 'model__n_estimators': 2590, 'model__reg_alpha': 5.844701932206553e-17, 'model__reg_lambda': 7.423292857634357e-18, 'model__subsample': 0.8614695032556878, 'ratio': LogRatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': 'passthrough'})
# L_BOL
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.6057049366944427, 'model__colsample_bytree': 0.6241961642267668, 'model__gamma': 6.7596143308323e-14, 'model__learning_rate': 0.007153524943906753, 'model__max_depth': 4, 'model__min_child_weight': 1, 'model__n_estimators': 2954, 'model__reg_alpha': 1.6181458347678753e-08, 'model__reg_lambda': 1e-20, 'model__subsample': 0.8973629767393609, 'ratio': RatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': StandardScaler()})
# MASS
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.9163328408599143, 'model__colsample_bytree': 0.5541836610756659, 'model__gamma': 2.328084513573961e-08, 'model__learning_rate': 0.009131058436472442, 'model__max_depth': 3, 'model__min_child_weight': 1, 'model__n_estimators': 1485, 'model__reg_alpha': 6.436156464791399e-05, 'model__reg_lambda': 2.6743552993254985e-08, 'model__subsample': 0.6414737493120946, 'ratio': LogRatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': StandardScaler()})
# DIAM
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.9696460315745749, 'model__colsample_bytree': 0.9889031638616339, 'model__gamma': 4.828705867240942e-07, 'model__learning_rate': 0.009003066489812606, 'model__max_depth': 3, 'model__min_child_weight': 8, 'model__n_estimators': 1176, 'model__reg_alpha': 0.0036188605722733635, 'model__reg_lambda': 1.3037147485971727e-05, 'model__subsample': 0.676313654107957, 'ratio': RatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': StandardScaler()})
# SURF_DENS
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.25, 'model__colsample_bytree': 1.0, 'model__gamma': 7.68052813907019e-13, 'model__learning_rate': 0.001746849208469677, 'model__max_depth': 4, 'model__min_child_weight': 3, 'model__n_estimators': 4450, 'model__reg_alpha': 4.744546505143453e-10, 'model__reg_lambda': 1e-20, 'model__subsample': 0.5069866188156872, 'ratio': LogRatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': 'passthrough'})
# TEMP
# OrderedDict({'impute': 'passthrough', 'model__colsample_bylevel': 0.7548329990330246, 'model__colsample_bytree': 0.8147210388431719, 'model__gamma': 4.939239401295727e-07, 'model__learning_rate': 0.007981222289450293, 'model__max_depth': 3, 'model__min_child_weight': 28, 'model__n_estimators': 689, 'model__reg_alpha': 7.591500509740298e-14, 'model__reg_lambda': 3.546170135807899e-05, 'model__subsample': 0.625484848874379, 'ratio': RatioGenerator(cols=['F8', 'F12', 'F24', 'F70']), 'scale': StandardScaler()})
