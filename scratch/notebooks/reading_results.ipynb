# %%
import pickle
import numpy as np
import pandas as pd
from pyhere import here

# %%
with open(here("pipeline/results", "rf_T_BOL_results.pkl"), 'rb') as file:
    rf_tbol_results = pickle.load(file)

print(rf_tbol_results)
# Out:
# {'CVscore': np.float64(-0.46720440645477107), 'best_params': OrderedDict({'impute': SimpleImputer(strategy='median'), 'model__bootstrap': True, 'model__max_depth': 20, 'model__max_features': None, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 742, 'scale': 'passthrough'}), 'logCVscore': np.float64(-0.005245686014681044), 'logbest_params': OrderedDict({'impute': SimpleImputer(), 'model__bootstrap': True, 'model__max_depth': 30, 'model__max_features': None, 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 1000, 'scale': StandardScaler()})}
