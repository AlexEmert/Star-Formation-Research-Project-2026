# %%
import pickle
import numpy as np
import pandas as pd
from pyhere import here

# %%
with open(here("pipeline/results", "L_BOL_results.pkl"), 'rb') as file:
    lbol_results = pickle.load(file)

print(lbol_results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open(here("pipeline/results", "L_BOL_results.pkl"), 'rb') as file:
# ----> 2     lbol_results = pickle.load(file)
#
# ModuleNotFoundError: No module named 'ratio_function'
